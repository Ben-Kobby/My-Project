# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
from skimage import io

#reading image from computer
img = io.imread("/home/data/Desktop/IMAGES/houses0.jpg")
plt.imshow(img)
print(img.shape)
# Out:
# (128, 128, 3)

# %%
#converting image from RGB to Gray_Scale
from skimage.color import rgb2gray
Gray_img = rgb2gray(img)
plt.imshow(Gray_img)
print(Gray_img.shape)
# Out:
# (128, 128)
